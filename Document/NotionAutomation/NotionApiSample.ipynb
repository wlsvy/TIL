# %% [markdown]
# ```json
# {
#     "archived": false,
#     "cover": null,
#     "created_by": {
#         "id": "cea61787-83cd-4812-ac29-c87af78a6065",
#         "object": "user"
#     },
#     "created_time": "2020-09-05T14:04:00.000Z",
#     "icon": null,
#     "id": "63d758d8-7e41-483e-bab7-def5d939f616",
#     "last_edited_by": {
#         "id": "cea61787-83cd-4812-ac29-c87af78a6065",
#         "object": "user"
#     },
#     "last_edited_time": "2022-05-09T13:05:00.000Z",
#     "object": "database",
#     "parent": {
#         "page_id": "6485647f-2f4b-4bfb-ac19-5211e43f91b0",
#         "type": "page_id"
#     },
#     "properties": {
#         "Created": {
#             "created_time": {},
#             "id": "%7Cdur",
#             "name": "Created",
#             "type": "created_time"
#         },
#         "Name": {
#             "id": "title",
#             "name": "Name",
#             "title": {},
#             "type": "title"
#         },
#         "Tags": {
#             "id": "qE%3Al",
#             "multi_select": {
#                 "options": [
#                     {
#                         "color": "red",
#                         "id": "c47fdc37-3853-4255-b8a8-74eaf89d9509",
#                         "name": "\ud0dc\uadf81"
#                     }
#                 ]
#             },
#             "name": "Tags",
#             "type": "multi_select"
#         }
#     },
#     "title": [
#         {
#             "annotations": {
#                 "bold": false,
#                 "code": false,
#                 "color": "default",
#                 "italic": false,
#                 "strikethrough": false,
#                 "underline": false
#             },
#             "href": null,
#             "plain_text": "Book",
#             "text": {
#                 "content": "Book",
#                 "link": null
#             },
#             "type": "text"
#         }
#     ],
#     "url": "https://www.notion.so/63d758d87e41483ebab7def5d939f616"
# }
# ```

# %%
myBookPageDbId = "63d758d87e41483ebab7def5d939f616"
authorization = "Bearer secret_V03L7Q3wQGwizHR1KStIE5yT3m1PM36JJhUouWfEdTj"
targetApiVersion = "2022-02-22"

notionApiReqHeader = {
    "Notion-Version": targetApiVersion,
    "Authorization": authorization
}

def retreiveDatabase(dbId):
    url = f'https://api.notion.com/v1/databases/{dbId}'
    rsp = requests.get(url, headers=notionApiReqHeader)
    return rsp.json()

def queryDatabase(dbId):
    url = f'https://api.notion.com/v1/databases/{dbId}/query'
    rsp = requests.post(url, headers=notionApiReqHeader)
    return rsp.json()

def retreivePage(pageId):
    url = f'https://api.notion.com/v1/pages/{pageId}'
    rsp = requests.get(url, headers=notionApiReqHeader)
    return rsp.json()

def retreiveBlock(blockId):
    url = f'https://api.notion.com/v1/blocks/{blockId}'
    rsp = requests.get(url, headers=notionApiReqHeader)
    return rsp.json()

def simpleJsonDump(jsonObj) :
    return json.dumps(jsonObj, sort_keys=True, indent=4)

# %%
import requests
import json

try:
    response = requests.get(databaseUrl(myBookPageDbId), headers=notionApiReqHeader)
    rspjson = response.json()
    dump = json.dumps(rspjson, sort_keys=True, indent=4)

except Exception as e:
    print(f'error {e}')
# Out:
# {'object': 'database', 'id': '63d758d8-7e41-483e-bab7-def5d939f616', 'cover': None, 'icon': None, 'created_time': '2020-09-05T14:04:00.000Z', 'created_by': {'object': 'user', 'id': 'cea61787-83cd-4812-ac29-c87af78a6065'}, 'last_edited_by': {'object': 'user', 'id': 'cea61787-83cd-4812-ac29-c87af78a6065'}, 'last_edited_time': '2022-05-09T13:05:00.000Z', 'title': [{'type': 'text', 'text': {'content': 'Book', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'Book', 'href': None}], 'properties': {'Tags': {'id': 'qE%3Al', 'name': 'Tags', 'type': 'multi_select', 'multi_select': {'options': [{'id': 'c47fdc37-3853-4255-b8a8-74eaf89d9509', 'name': '태그1', 'color': 'red'}]}}, 'Created': {'id': '%7Cdur', 'name': 'Created', 'type': 'created_time', 'created_time': {}}, 'Name': {'id': 'title', 'name': 'Name', 'type': 'title', 'title': {}}}, 'parent': {'type': 'page_id', 'page_id': '6485647f-2f
# ...

# %%
response = requests.get(databaseUrl(myBookPageDbId), headers=notionApiReqHeader)
rspJson = response.json()

# %%
#queryRes = queryDatabase(myBookPageDbId)
#print(simpleJsonDump(queryRes))

#t = simpleJsonDump(queryRes["results"])
#print(t)

def queryDbPages(dbId) :
    json = queryDatabase(dbId)
    pages = [p for p in json["results"] if p["object"] == 'page']
    for p in pages:
        pid = p["id"]
        pjson = retreivePage(pid)
        bjson = retreiveBlock(pid)
        print(simpleJsonDump(bjson))
        print(simpleJsonDump(pjson))

queryDbPages(myBookPageDbId)
# Out:
# {
#     "archived": false,
#     "child_page": {
#         "title": "\uc624\ubc84 \ub354 \ud638\ub77c\uc774\uc98c"
#     },
#     "created_by": {
#         "id": "cea61787-83cd-4812-ac29-c87af78a6065",
#         "object": "user"
#     },
#     "created_time": "2022-05-09T13:05:00.000Z",
#     "has_children": true,
#     "id": "7e449936-bb63-4f13-898c-7e64c8988a08",
#     "last_edited_by": {
#         "id": "cea61787-83cd-4812-ac29-c87af78a6065",
#         "object": "user"
#     },
#     "last_edited_time": "2022-05-09T13:25:00.000Z",
#     "object": "block",
#     "type": "child_page"
# }
# {
#     "archived": false,
#     "cover": null,
#     "created_by": {
#         "id": "cea61787-83cd-4812-ac29-c87af78a6065",
#         "object": "user"
#     },
#     "created_time": "2022-05-09T13:05:00.000Z",
#     "icon": null,
#     "id": "7e449936-bb63-4f13-898c-7e64c8988a08",
#     "last_edited_by": {
#         "id": "cea61787-83cd-4812-ac29-c87af78a6065",
#         "object": "user"
# ...
